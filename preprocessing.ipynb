# %% [markdown]
# # Task 2: 3D Object pre-processing

# %%
import trimesh
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shutil
import subprocess
import pymeshlab

ORIGINAL_SHAPES_PATH = 'original_shapes'
RESAMPLED_SHAPES_PATH = 'resampled_shapes'

# %% [markdown]
# ## Step 2.1: Analyzing a single shape

# %%
def analyze_shape(filepath):
    '''
    Analyze a 3D shape using Trimesh and return the required information.
    :param filepath: Path to the OBJ file
    '''
    # Load the mesh using Trimesh
    mesh = trimesh.load(filepath)
    
    num_vertices = len(mesh.vertices)  # Number of vertices
    num_faces = len(mesh.faces)  # Number of faces (triangles)
    face_type = "Triangles"  # Face type (triangles by default for OBJ)
    
    # Axis-aligned bounding box (AABB)
    aabb_min, aabb_max = mesh.bounds
    bounding_box = {
        "min_bound": aabb_min.tolist(),  # Min corner of the bounding box
        "max_bound": aabb_max.tolist()   # Max corner of the bounding box
    }

    has_holes = not mesh.is_watertight  # Has holes or not
    outlier_low = True if num_vertices <= 100 or num_faces <= 100 else False  # Low outlier
    outlier_high = True if num_vertices >= 25000 or num_faces >= 25000 else False  # High outlier

    # Return dictionary of extracted data
    return {
        "vertices": num_vertices,
        "faces": num_faces,
        "face_type": face_type,
        "bounding_box": bounding_box,
        "has_holes": has_holes,
        "outlier_low": outlier_low,
        "outlier_high": outlier_high
    }
    

def analyze_database(labeled_db_path):
    '''
    Iteratively analyze all 3D shapes within the database.
    :param labeled_db_path: Path to the root of the labeled database
    '''
    results = []

    for category in os.listdir(labeled_db_path):
        category_path = os.path.join(labeled_db_path, category)

        if os.path.isdir(category_path):
            for shape_file in os.listdir(category_path):
                if shape_file.endswith('.obj'):
                    filepath = os.path.join(category_path, shape_file)
                    shape_info = {}
                    shape_info["file_name"] = shape_file  # Add the filename of the shape
                    shape_info["obj_class"] = category  # Add class (category) of the shape
                    # Analyze each shape
                    shape_info.update(analyze_shape(filepath))
                    shape_info["file_path"] = os.path.join(category_path, shape_file)  # Add class (category) of the shape
                    
                    results.append(shape_info)

    return results


shapes_data = analyze_database("original_shapes")
shapes_data_df = pd.DataFrame(shapes_data)
shapes_data_df.to_csv("outputs/data/shapes_data.csv")
shapes_data_df.head()
# Out:
#    file_name        obj_class  vertices  faces  face_type  \
# 0  m1337.obj  AircraftBuoyant       201    340  Triangles
# 1  m1338.obj  AircraftBuoyant      8761  16960  Triangles
# 2  m1339.obj  AircraftBuoyant      1878   6173  Triangles
# 3  m1340.obj  AircraftBuoyant       778   1457  Triangles
# 4  m1341.obj  AircraftBuoyant       425    824  Triangles
#
#                                         bounding_box  has_holes  outlier_low  \
# 0  {'min_bound': [0.025, 0.025, 0.025], 'max_boun...       True        False
# 1  {'min_bound': [0.025, 0.025, 0.025], 'max_boun...       True        False
# 2  {'min_bound': [0.025, 0.025, 0.025], 'max_boun...       True        False
# 3  {'min_bound': [0.025, 0.025, 0.025], 'max_boun...       True        False
# 4  {'min_bound': [0.025, 0.025, 0.025], 'max_boun...       True        False
#
#    outlier_high                                  file_path
# 0         False  original_shapes\AircraftBuoyant\m1337.obj
# 1         False  original_shapes\AircraftBuoyant\m1338.obj
# 2         False  original_shapes\AircraftBuoyant\m1339.obj
# 3         False  original_shapes\AircraftBuoyant\m1340.obj
# 4         False  original_shapes\AircraftBuoyant\m1341.obj

# %% [markdown]
# ## Step 2.2: Statistics over the whole database

# %% [markdown]
# ### 1. Plot data to observe their distribution

# %%
def vertex_face_distribution_plot(shapes_data, vertices, faces):
    plt.figure(figsize=(12, 4))

    # Histogram for vertices
    plt.subplot(1, 2, 1)
    plt.hist(shapes_data[vertices], bins=30, color='purple', alpha=0.7)
    plt.title('Distribution of Vertices')
    plt.xlabel('Number of Vertices')
    plt.ylabel('Number of Shapes')

    # Histogram for faces
    plt.subplot(1, 2, 2)
    plt.hist(shapes_data[faces], bins=30, color='red', alpha=0.7)
    plt.title('Distribution of Faces')
    plt.xlabel('Number of Faces')
    plt.ylabel('Number of Shapes')

    plt.tight_layout()
    plt.show()

# Load the CSV file
shapes_data_df = pd.read_csv('outputs/data/shapes_data.csv')

# Plot data to observe their distribution
vertex_face_distribution_plot(shapes_data_df, 'vertices', 'faces')

# %% [markdown]
# ### 2. Calculate global statistics

# %%
# Compute mean and standard deviation on both vertices and faces
mean_vertices = shapes_data_df['vertices'].mean()
std_vertices = shapes_data_df['vertices'].std()

mean_faces = shapes_data_df['faces'].mean()
std_faces = shapes_data_df['faces'].std()

# Compute other statistics
total_shapes = shapes_data_df.shape[0]
has_holes_count = shapes_data_df[shapes_data_df['has_holes']==True]['has_holes'].count() 
outlier_low_count = shapes_data_df[shapes_data_df['outlier_low']==True]['outlier_low'].count()
outlier_high_count = shapes_data_df[shapes_data_df['outlier_high']==True]['outlier_high'].count()

# Save the data in a csv
global_statistics = {"total_shapes": total_shapes,
                     "mean_vertices": mean_vertices,
                     "std_vertices": std_vertices,
                     "mean_faces": mean_faces,
                     "std_faces": std_faces,
                     "has_holes_count": has_holes_count,
                     "outlier_low_count": outlier_low_count,
                     "outlier_high_count": outlier_high_count,}

pd.DataFrame([global_statistics]).to_csv("outputs/data/global_statistics.csv")

# Save list with classes
classes_list = shapes_data_df.obj_class.unique()
with open('outputs/data/classes.txt', 'w') as f:
    for obj_class in classes_list:
        f.write(f"{obj_class}\n")

# %% [markdown]
# ### 3. Save normal and outlier samples in new folder

# %%
# Sample a normal shape from the 'House' category
normal_samples = shapes_data_df[(shapes_data_df['outlier_low'] == False) & (shapes_data_df['obj_class'] == 'House')].sample(n=1)

# Sample 3 outliers from the 'House' category
outlier_samples = shapes_data_df[(shapes_data_df['outlier_low'] == True) & (shapes_data_df['obj_class'] == 'House')].sample(n=3)

# Save the normal and outlier sample paths
normal_sample_paths = normal_samples['file_path'].values
outlier_sample_paths = outlier_samples['file_path'].values

print(f'Normal shapes: {normal_sample_paths}')
print(f'Outlier shapes: {outlier_sample_paths}')

# Copy them from the original directory to a separate directory in the 'outputs' folder
dst = 'outputs/shapes'

for i, src_sample_path in enumerate(normal_sample_paths):
    destination = f'{dst}/normal_{i+1}.obj'
    shutil.copy(src_sample_path, destination)
    
for i, src_sample_path in enumerate(outlier_sample_paths):
    destination = f'{dst}/outlier_{i+1}.obj'
    shutil.copy(src_sample_path, destination)

print('COPIED!')
# Out:
# Normal shapes: ['original_shapes\\House\\m439.obj']
# Outlier shapes: ['original_shapes\\House\\m423.obj' 'original_shapes\\House\\m462.obj'
#  'original_shapes\\House\\m434.obj']
# COPIED!

# %% [markdown]
# ## Step 2.3. Resampling outliers

# %% [markdown]
# ### 1. Resample the low outliers and replace the previous file

# %%
def isotropic_remesh(mesh):
    '''
    Perform isotropic remeshing on a mesh using PyMeshLab.
    :param mesh: The input mesh (as a Trimesh object)
    :return: Remeshed mesh (as a Trimesh object)
    '''
    # Save the mesh to a temporary file
    temp_input_path = 'temp_input.obj'
    temp_output_path = 'temp_remeshed.obj'
    mesh.export(temp_input_path)

    # Create a new MeshSet
    ms = pymeshlab.MeshSet()
    # Load the mesh
    ms.load_new_mesh(temp_input_path)
    # Apply isotropic remeshing
    target_edge_length = 0.1  # Adjust as needed
    ms.apply_filter('meshing_isotropic_explicit_remeshing',
                    targetlen=pymeshlab.PercentageValue(target_edge_length),
                    iterations=5)
    # Save the remeshed mesh
    ms.save_current_mesh(temp_output_path)

    # Load the remeshed mesh back into trimesh
    remeshed_mesh = trimesh.load(temp_output_path)

    # Clean up temporary files
    os.remove(temp_input_path)
    os.remove(temp_output_path)

    return remeshed_mesh


def resample_low_outliers(mesh):
    '''
    Use the Catmull-Clark Subdivider to resample low outlier meshes.
    :param mesh: The input mesh (as a Trimesh object)
    :return: Resampled mesh (as a Trimesh object)
    '''
    # Save the mesh to a temporary OFF file
    input_off_file = 'temp_input.off'
    output_off_file = 'temp_output.off'
    mesh.export(input_off_file)

    # Path to the Catmull-Clark subdivider JAR file
    jar_file = 'tools/catmullclark.jar'
    
    if not os.path.isfile(jar_file):
        print(f"Jar file not found at {jar_file}")
        return mesh  # Return the original mesh if the JAR file is missing

    # Command to run the Catmull-Clark subdivision
    cmd = ['java', '-jar', jar_file, input_off_file, output_off_file]

    try:
        # Run the command and capture stdout and stderr
        result = subprocess.run(cmd, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

        # Check if output file exists
        if not os.path.isfile(output_off_file):
            print(f"Output file {output_off_file} was not created.")
            return mesh  # Return the original mesh if output file is missing

        # Check if output file is not empty
        if os.path.getsize(output_off_file) == 0:
            print(f"Output file {output_off_file} is empty.")
            return mesh  # Return the original mesh if output file is empty

        # Load the resampled mesh from the output OFF file
        resampled_mesh = trimesh.load(output_off_file)

        # Clean up temporary files
        os.remove(input_off_file)
        os.remove(output_off_file)

        return resampled_mesh

    except subprocess.CalledProcessError as e:
        print(f"Error in subdivision process: {e}")
        print("Subprocess stdout:", e.stdout)
        print("Subprocess stderr:", e.stderr)
        return mesh  # Return the original mesh if the subdivision fails
    
    
def process_meshes(df, resampled_root):
    '''
    Apply isotropic remeshing to all meshes and Catmull-Clark subdivision to low outliers.
    :param df: DataFrame containing shape metadata (shapes_data_df)
    :param resampled_root: Path to the resampled database folder (e.g., 'resampled_shapes')
    '''
    for index, row in df.iterrows():
        obj_class = row['obj_class']
        file_name = row['file_name']
        file_path = row['file_path']
        
        # Construct the path to the file in the resampled folder
        resampled_file_path = os.path.join(resampled_root, obj_class, file_name)

        # Load the mesh
        mesh = trimesh.load(file_path)

        

        # For low outliers, apply Catmull-Clark subdivision
        if row['outlier_low']:
            # Apply isotropic remeshing 
            print(f"Applying isotropic remeshing to {file_name}")
            remeshed_mesh = isotropic_remesh(mesh)
        
            print(f"Applying Catmull-Clark subdivision to {file_name} (low outlier)")
            resampled_mesh = resample_low_outliers(remeshed_mesh)
        else:
            resampled_mesh = mesh

        # Ensure the directory exists
        os.makedirs(os.path.dirname(resampled_file_path), exist_ok=True)

        # Save the resampled file in the resampled folder
        resampled_mesh.export(resampled_file_path)
  
    
# Example usage after you manually copy the database
process_meshes(shapes_data_df, RESAMPLED_SHAPES_PATH)
# Out:
# Applying isotropic remeshing to m59.obj
# Applying Catmull-Clark subdivision to m59.obj (low outlier)
# Applying isotropic remeshing to m43.obj
# Applying Catmull-Clark subdivision to m43.obj (low outlier)
# Applying isotropic remeshing to m50.obj
# Applying Catmull-Clark subdivision to m50.obj (low outlier)
# Applying isotropic remeshing to m390.obj
# Applying Catmull-Clark subdivision to m390.obj (low outlier)
# Applying isotropic remeshing to m392.obj
# Applying Catmull-Clark subdivision to m392.obj (low outlier)
# Applying isotropic remeshing to D01053.obj
# Applying Catmull-Clark subdivision to D01053.obj (low outlier)
# Applying isotropic remeshing to m1605.obj
# Applying Catmull-Clark subdivision to m1605.obj (low outlier)
# Applying isotropic remeshing to D01071.obj
# Applying Catmull-Clark subdivision to D01071.obj (low outlier)
# Applying isotropic remeshing to D01085.obj
# Applying Catmull-Clark subdivision to D01085.obj (low outlier)
# Applying isotropic remeshing to D01102.obj
# Applying Catmull-Clark subdivision to D01102.obj (low outlier)
# Applying isotropic remeshing to m1765.obj
# Applying Catmull-Clark subdivision to m1765.obj (low outlier)
# Applying isotropic remeshing to m1766.obj
# Applying Catmull-Clark subdivision to m1766.obj (low outlier)
# Applying isotropic remeshing to m1769.obj
# Applying Catmull-Clark subdivision to m1769.obj (low outlier)
# Applying isotropic remeshing to m500.obj
# Applying Catmull-Clark subdivision to m500.obj (low outlier)
# Applying isotropic remeshing to D00378.obj
# Applying Catmull-Clark subdivision to D00378.obj (low outlier)
# Applying isotropic remeshing to m606.obj
# Applying Catmull-Clark subdivision to m606.obj (low outlier)
# Applying isotropic remeshing to m611.obj
# Applying Catmull-Clark subdivision to m611.obj (low outlier)
# Applying isotropic remeshing to D01121.obj
# Applying Catmull-Clark subdivision to D01121.obj (low outlier)
# Applying isotropic remeshing to D01139.obj
# Applying Catmull-Clark subdivision to D01139.obj (low outlier)
# Applying isotropic remeshing to D01143.obj
# Applying Catmull-Clark subdivision to D01143.obj (low outlier)
# Applying isotropic remeshing to D01144.obj
# Applying Catmull-Clark subdivision to D01144.obj (low outlier)
# Applying isotropic remeshing to D01177.obj
# Applying Catmull-Clark subdivision to D01177.obj (low outlier)
# Applying isotropic remeshing to D01194.obj
# Applying Catmull-Clark subdivision to D01194.obj (low outlier)
# Applying isotropic remeshing to m1708.obj
# Applying Catmull-Clark subdivision to m1708.obj (low outlier)
# Applying isotropic remeshing to m1711.obj
# Applying Catmull-Clark subdivision to m1711.obj (low outlier)
# Applying isotropic remeshing to D00115.obj
# Applying Catmull-Clark subdivision to D00115.obj (low outlier)
# Applying isotropic remeshing to D00709.obj
# Applying Catmull-Clark subdivision to D00709.obj (low outlier)
# Applying isotropic remeshing to m622.obj
# Applying Catmull-Clark subdivision to m622.obj (low outlier)
# Applying isotropic remeshing to m623.obj
# Applying Catmull-Clark subdivision to m623.obj (low outlier)
# Applying isotropic remeshing to m624.obj
# Applying Catmull-Clark subdivision to m624.obj (low outlier)
# Applying isotropic remeshing to m651.obj
# Applying Catmull-Clark subdivision to m651.obj (low outlier)
# Applying isotropic remeshing to m423.obj
# Applying Catmull-Clark subdivision to m423.obj (low outlier)
# Applying isotropic remeshing to m434.obj
# Applying Catmull-Clark subdivision to m434.obj (low outlier)
# Applying isotropic remeshing to m462.obj
# Applying Catmull-Clark subdivision to m462.obj (low outlier)
# Applying isotropic remeshing to m1231.obj
# Applying Catmull-Clark subdivision to m1231.obj (low outlier)
# Applying isotropic remeshing to m1300.obj
# Applying Catmull-Clark subdivision to m1300.obj (low outlier)
# Applying isotropic remeshing to m1301.obj
# Applying Catmull-Clark subdivision to m1301.obj (low outlier)
# Applying isotropic remeshing to D01175.obj
# Applying Catmull-Clark subdivision to D01175.obj (low outlier)
# Applying isotropic remeshing to m778.obj
# Applying Catmull-Clark subdivision to m778.obj (low outlier)
# Applying isotropic remeshing to m782.obj
# Applying Catmull-Clark subdivision to m782.obj (low outlier)
# Applying isotropic remeshing to m783.obj
# Applying Catmull-Clark subdivision to m783.obj (low outlier)
# Applying isotropic remeshing to m784.obj
# Applying Catmull-Clark subdivision to m784.obj (low outlier)
# Applying isotropic remeshing to m836.obj
# Applying Catmull-Clark subdivision to m836.obj (low outlier)
# Applying isotropic remeshing to m840.obj
# Applying Catmull-Clark subdivision to m840.obj (low outlier)
# Applying isotropic remeshing to m841.obj
# Applying Catmull-Clark subdivision to m841.obj (low outlier)
# Applying isotropic remeshing to m793.obj
# Applying Catmull-Clark subdivision to m793.obj (low outlier)
# Applying isotropic remeshing to m818.obj
# Applying Catmull-Clark subdivision to m818.obj (low outlier)
# Applying isotropic remeshing to m827.obj
# Applying Catmull-Clark subdivision to m827.obj (low outlier)
# Applying isotropic remeshing to m1032.obj
# Applying Catmull-Clark subdivision to m1032.obj (low outlier)
# Applying isotropic remeshing to m983.obj
# Applying Catmull-Clark subdivision to m983.obj (low outlier)
# Applying isotropic remeshing to D00188.obj
# Applying Catmull-Clark subdivision to D00188.obj (low outlier)
# Applying isotropic remeshing to D00421.obj
# Applying Catmull-Clark subdivision to D00421.obj (low outlier)
# Applying isotropic remeshing to m764.obj
# Applying Catmull-Clark subdivision to m764.obj (low outlier)
# Applying isotropic remeshing to m870.obj
# Applying Catmull-Clark subdivision to m870.obj (low outlier)
# Applying isotropic remeshing to m871.obj
# Applying Catmull-Clark subdivision to m871.obj (low outlier)
# Applying isotropic remeshing to m874.obj
# Applying Catmull-Clark subdivision to m874.obj (low outlier)
# Applying isotropic remeshing to m876.obj
# Applying Catmull-Clark subdivision to m876.obj (low outlier)
# Applying isotropic remeshing to m877.obj
# Applying Catmull-Clark subdivision to m877.obj (low outlier)
# Applying isotropic remeshing to m881.obj
# Applying Catmull-Clark subdivision to m881.obj (low outlier)
# Applying isotropic remeshing to m883.obj
# Applying Catmull-Clark subdivision to m883.obj (low outlier)
# Applying isotropic remeshing to m888.obj
# Applying Catmull-Clark subdivision to m888.obj (low outlier)
# Applying isotropic remeshing to m894.obj
# Applying Catmull-Clark subdivision to m894.obj (low outlier)
# Applying isotropic remeshing to m895.obj
# Applying Catmull-Clark subdivision to m895.obj (low outlier)
# Applying isotropic remeshing to m905.obj
# Applying Catmull-Clark subdivision to m905.obj (low outlier)
# Applying isotropic remeshing to m912.obj
# Applying Catmull-Clark subdivision to m912.obj (low outlier)
# Applying isotropic remeshing to m915.obj
# Applying Catmull-Clark subdivision to m915.obj (low outlier)
# Applying isotropic remeshing to m917.obj
# Applying Catmull-Clark subdivision to m917.obj (low outlier)
# Applying isotropic remeshing to m919.obj
# Applying Catmull-Clark subdivision to m919.obj (low outlier)
# Applying isotropic remeshing to D00015.obj
# Applying Catmull-Clark subdivision to D00015.obj (low outlier)
# Applying isotropic remeshing to D00426.obj
# Applying Catmull-Clark subdivision to D00426.obj (low outlier)
# Applying isotropic remeshing to D00472.obj
# Applying Catmull-Clark subdivision to D00472.obj (low outlier)
# Applying isotropic remeshing to m922.obj
# Applying Catmull-Clark subdivision to m922.obj (low outlier)
# Applying isotropic remeshing to m931.obj
# Applying Catmull-Clark subdivision to m931.obj (low outlier)
# Applying isotropic remeshing to m933.obj
# Applying Catmull-Clark subdivision to m933.obj (low outlier)
# Applying isotropic remeshing to m937.obj
# Applying Catmull-Clark subdivision to m937.obj (low outlier)
# Applying isotropic remeshing to D00592.obj
# Applying Catmull-Clark subdivision to D00592.obj (low outlier)
# Applying isotropic remeshing to m845.obj
# Applying Catmull-Clark subdivision to m845.obj (low outlier)
# Applying isotropic remeshing to m851.obj
# Applying Catmull-Clark subdivision to m851.obj (low outlier)
# Applying isotropic remeshing to m853.obj
# Applying Catmull-Clark subdivision to m853.obj (low outlier)
# Applying isotropic remeshing to m854.obj
# Applying Catmull-Clark subdivision to m854.obj (low outlier)
# Applying isotropic remeshing to m855.obj
# Applying Catmull-Clark subdivision to m855.obj (low outlier)
# Applying isotropic remeshing to m856.obj
# Applying Catmull-Clark subdivision to m856.obj (low outlier)
# Output file temp_output.off was not created.
# Applying isotropic remeshing to m858.obj
# Applying Catmull-Clark subdivision to m858.obj (low outlier)
# Applying isotropic remeshing to m860.obj
# Applying Catmull-Clark subdivision to m860.obj (low outlier)
# Applying isotropic remeshing to m1450.obj
# Applying Catmull-Clark subdivision to m1450.obj (low outlier)
# Applying isotropic remeshing to m1673.obj
# Applying Catmull-Clark subdivision to m1673.obj (low outlier)
# Applying isotropic remeshing to m1674.obj
# Applying Catmull-Clark subdivision to m1674.obj (low outlier)
# Applying isotropic remeshing to m1675.obj
# Applying Catmull-Clark subdivision to m1675.obj (low outlier)
# Applying isotropic remeshing to m1684.obj
# Applying Catmull-Clark subdivision to m1684.obj (low outlier)
# Applying isotropic remeshing to D00474.obj
# Applying Catmull-Clark subdivision to D00474.obj (low outlier)
# Applying isotropic remeshing to m1102.obj
# Applying Catmull-Clark subdivision to m1102.obj (low outlier)
# Applying isotropic remeshing to m1082.obj
# Applying Catmull-Clark subdivision to m1082.obj (low outlier)
# Applying isotropic remeshing to m1097.obj
# Applying Catmull-Clark subdivision to m1097.obj (low outlier)
# Applying isotropic remeshing to m533.obj
# Applying Catmull-Clark subdivision to m533.obj (low outlier)
# Applying isotropic remeshing to m746.obj
# Applying Catmull-Clark subdivision to m746.obj (low outlier)

# %% [markdown]
# ### 2. Keep a before-resampling and after-resampling for visualization

# %%
dst = 'outputs/shapes'

# Select a random non-outlier shape from the 'House' category
outlier_before_path = shapes_data_df[(shapes_data_df['outlier_low'] == True) & 
                                     (shapes_data_df['obj_class'] == 'House')].sample(n=1)['file_path'].values[0]

# Construct the path for the resampled shape
outlier_after_path = os.path.join(RESAMPLED_SHAPES_PATH, 
                                  os.path.relpath(outlier_before_path, start='original_shapes'))

# Ensure the output folder exists
os.makedirs(dst, exist_ok=True)

# Save the before resampling file
destination_before_resampling = os.path.join(dst, 'before_resampling.obj')
shutil.copy(outlier_before_path, destination_before_resampling)

# Save the after resampling file
destination_after_resampling = os.path.join(dst, 'after_resampling.obj')
shutil.copy(outlier_after_path, destination_after_resampling)
# Out:
# 'outputs/shapes\\after_resampling.obj'
